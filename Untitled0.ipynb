# %% [markdown]
# <a href="https://colab.research.google.com/github/priyadarshinig15/mnist-digit-classifier/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_openml

# %%
mnist = fetch_openml('mnist_784')

# %%
print(f"Keys in mnist object: {mnist.keys()}")
print(f"Shape of data: {mnist.data.shape}")
print(f"Shape of target: {mnist.target.shape}")
# Out:
# Keys in mnist object: dict_keys(['data', 'target', 'frame', 'categories', 'feature_names', 'target_names', 'DESCR', 'details', 'url'])
# Shape of data: (70000, 784)
# Shape of target: (70000,)

# %%
x, y = mnist['data'], mnist['target']

# %%
x.shape
# Out:
# (70000, 784)

# %%
y.shape
# Out:
# (70000,)

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
some_digit = x.iloc[36000].values
some_digite_image = some_digit.reshape(28,28)

# %%
from matplotlib.image import NEAREST
plt.imshow(some_digite_image, cmap = matplotlib.cm.binary,interpolation= "nearest")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(27.5), np.float64(27.5), np.float64(-0.5))

# %%
y[36000]
# Out:
# '9'

# %%
x_train = x[:60000]
x_test = x[60000:]

# %%
y_train = y[:60000]
y_test = y[60000:]

# %%
import numpy as np
shuffle_index = np.random.permutation(60000)
x_train, y_train = x_train.iloc[shuffle_index], y_train.iloc[shuffle_index]

# %% [markdown]
# ##**Creating a 2** **detector**

# %%
y_train = y_train.astype(np.int8)
y_test = y_test.astype(np.int8)
y_train_2 = (y_train == 2)
y_test_2 = (y_test == 2)

# %%
y_train
# Out:
# 24491    2
# 20556    1
# 48107    2
# 54204    6
# 32864    8
#         ..
# 43434    2
# 59865    8
# 44115    8
# 40538    6
# 14546    4
# Name: class, Length: 60000, dtype: int8

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(max_iter=1000)

# %%
clf.fit(x_train,y_train_2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %%
clf.predict([some_digit])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([False])

# %%
from sklearn.model_selection import cross_val_score
a = cross_val_score(clf,x_train, y_train_2, cv = 3, scoring="accuracy")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
a.mean()
# Out:
# np.float64(0.9775833333333334)
